# %% [markdown]
# ### Importing necessary Libarary and Loading the data

# %%
#Importing Necessary Libraries

import nltk
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import pandas as pd
import string
import csv
import sys

# %%
# Load the CSV file
csv_filename = "./sentences.csv"
data = pd.read_csv(csv_filename)

# %%
data
# Out:
#                                             Sentences
# 0   Home » Lifestyle » Art » Prakriti-Where the Go...
# 1   With the sound of nature reverberating in the ...
# 2   In addition, the exhibition includes unique pa...
# 3   Prakriti-Where the Gods Reside is full of such...
# 4   The exhibition features traditional and modern...
# 5   The animal series of the exhibition showcases ...
# 6   The exhibition also has the Shiva Parvati seri...
# 7   Prakriti-Where the Gods Reside also has abstra...
# 8   In addition, one can witness the finest statue...
# 9   Prakriti-Where the Gods Reside has set a prece...
# 10  It has provided a platform for traditional art...
# 11  This has shown how adaptive these artists are ...
# 12  Then, following the new trend, the exhibition ...
# 13  Usually, traditional artists are reluctant to ...
# 14  However, in this exhibition, viewers can witne...
# 15  Prajwol Shakya, director of the gallery said, ...
# 16  ” Moreover, he says that the exhibition is a c...
# 17  Likewise, Prakriti-Where the Gods Reside showc...
# 18  One of his paintings in the exhibition feature...
# 19  This realistic painting is pleasing to the eye...
# 20  To understand the depth of the details in pain...
# 21  And if you look at the painting closer with a ...
# 22  “Usually in Newa community when the bride is w...
# 23  ” Udaya Charan is known for his detailed works...
# 24  Udaya Charan also helped to envision the icono...
# 25  Goddess Annapurna is known for her blessing wi...
# 26  Even at her shrines, such as the one at Asan, ...
# 27  However, it was late Purna Man Shakya who rece...
# 28  Then with the help of Udaya Charan, the iconog...
# 29  In the exhibition, you can witness the life-si...
# 30  Similarly, you can also see a metal statue of ...
# 31  “To resonate with the younger generation and e...
# 32  ” The exhibition lets you explore connectednes...
# 33  Additionally, the exhibition demonstrates the ...
# 34            The exhibition continues till August 26
# 35    Shrestha is a senior sub-editor at Onlinekhabar
# 36                   Contact her at [email protected]

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Loading sentences csv and preprocessing all the sentences

# %%
# Preprocess the content using NLTK
nltk.download('stopwords')
nltk.download('punkt')
stop_words = set(stopwords.words('english'))
ps = PorterStemmer()

preprocessed_content = []
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Nandan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Nandan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### Testing Function for preprocessing(Functional Approach)

# %%
def preprocess( sentences):
        ps = PorterStemmer()
        stop_words = set(stopwords.words('english'))
        preprocessed = []
        
        for sent in sentences:
            words = word_tokenize(sent)
            filtered_words = [ps.stem(word) for word in words if word.lower() not in stop_words and word not in string.punctuation]
            processed = " ".join(filtered_words)
            preprocessed.append(processed)
        
        return preprocessed

# %%
# Preprocessed question
question = ["What did Nepal export?"]

# %%
print(preprocess(question))
# Out:
# ['nepal export']

# %% [markdown]
# ### Class for preprocessing all the sentences(OOPS Approach)

# %%
#importing Necessary Library

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import string

# Download Necessary daras
nltk.download('punkt')
nltk.download('stopwords')

class TextPreprocessor:
    
    def __init__(self):
        self.ps = PorterStemmer()
        self.stop_words = set(stopwords.words('english'))
    
    def preprocess(self, sentences):
        preprocessed = []
        
        for sent in sentences:
            words = word_tokenize(sent)
            filtered_words = [self.ps.stem(word) for word in words if word.lower() not in self.stop_words and word not in string.punctuation]
            processed = " ".join(filtered_words)
            preprocessed.append(processed)
        
        return preprocessed
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Nandan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Nandan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Testing the class
sentences = ["I am running in the park."]
preprocessor = TextPreprocessor()
preprocessed_sentences = preprocessor.preprocess(sentences)
print(preprocessed_sentences)
# Out:
# ['run park']

# %% [markdown]
# ### preprocessing all the scraped sentences using the Class

# %%
content_column = data['Sentences']

# %%
# Convert the column values to a list
sentences = content_column.tolist()

# instantiing a object
preprocessor = TextPreprocessor()

#passing the sentences to the class
preprocessed_sentences = preprocessor.preprocess(sentences)

#output
print(preprocessed_sentences)
# Out:
# ['home » lifestyl » art » prakriti-wher god resid explor artist evolut enter bodhisattva galleri pulchowk peac sound run water bird welcom', 'sound natur reverber background come across first section ‘ prakriti-wher god resid ’ featur statu filigre work preciou semi-preci stone bird artist pradip shakya', 'addit exhibit includ uniqu paint artist puspa lal dangol paint bird use feather canva', 'prakriti-wher god resid full interest artwork', 'exhibit featur tradit modern artwork experienc artist creat uniqu blend give art lover wholesom experi', 'anim seri exhibit showcas work artist lok chitrakar udaya charan shrestha meena dangol puspa lal dangol pradip shakya', 'exhibit also shiva parvati seri display work udaya charan samundra man singh shrestha', 'prakriti-wher god resid also abstract paint theme pancha buddha five element raj prakash tuladhar ram prakash shrestha rajan sangache ritesh shahi', 'addit one wit finest statu differ god goddess made metal artist aneel shakya rajan shakya arjun shakya rajesh awal bijay shakya sanu maharjan birendra shakya sunni shakya gahendra shakya phal saman shakya nilesh shakya', 'prakriti-wher god resid set preced curat tradit art', 'provid platform tradit artist ventur new realm includ abstract art', 'shown adapt artist collabor quit beauti', 'follow new trend exhibit also display captiv digit anim goddess annapurna design engag attract younger gener', 'usual tradit artist reluct explor modern aspect art form', 'howev exhibit viewer wit tradit artist raj prakash tuladhar ’ first-ev abstract paint theme pancha buddha five element', 'prajwol shakya director galleri said “ object present exhibit unifi experi peopl age transcend cultur gener barrier', '” moreov say exhibit celebr rich artist legaci nepal intertwin contemporari element aim nurtur appreci art cultur spiritu among divers commun countri', 'likewis prakriti-wher god resid showcas never seen paint senior artist udaya charan', 'one paint exhibit featur ceremoni newa commun mother-in-law welcom daughter-in-law wed ceremoni', 'realist paint pleas eye work everi singl detail paint', 'understand depth detail paint use magnifi glass avail galleri', 'look paint closer magnifi glass see shine cloth daughter-in-law mother-in-law ’ cloth dull without shine', '“ usual newa commun bride welcom first time hous mother-in-law daughter-in-law wear rich red gold brocad attir shawl ” prajwol say “ senior artist udaya charan shrestha kept detail mind time mothers-in-law wear old bridal set ceremoni ’ tint cloth', '” udaya charan known detail work one finest tradit artist nepal', 'udaya charan also help envis iconograph imag goddess annapurna galleri', 'goddess annapurna known bless never-end suppli anna food grain also known incarn goddess parvati', 'even shrine one asan devote limit wit kalash vase plenti manifest goddess', 'howev late purna man shakya receiv order goddess annapurna ’ statu', 'help udaya charan iconograph imag goddess annapurna newa style creat purna man commiss sculptor make idol', 'exhibit wit life-s digit anim goddess annapurna project three side galleri', 'similarli also see metal statu goddess annapurna creat lost wax process use mercuri gold gild copper opposit anim', '“ reson younger gener embrac modern technolog prakriti also incorpor digit anim goddess annapurna ” say prajwol “ anim envis offer dynam immers experi visitor align evolv prefer contemporari audienc connect nepal ’ profound cultur heritag novel way', '” exhibit let explor connected natur real spiritu world artwork display give wholesom experi', 'addit exhibit demonstr willing establish artist delv unchart territori maintain core aesthet valu', 'exhibit continu till august 26', 'shrestha senior sub-editor onlinekhabar', 'contact email protect']

# %% [markdown]
# ### Saving Preprocessed data

# %%
# Create a DataFrame with preprocessed sentences
preprocessed_data = pd.DataFrame({'sentences': preprocessed_sentences})

# Save the preprocessed data to a CSV file
preprocessed_data.to_csv('preprocessed_content.csv', index=False)

# %%
preprocess_df = pd.read_csv('./preprocessed_content.csv')
preprocess_df
# Out:
#                                             sentences
# 0   home » lifestyl » art » prakriti-wher god resi...
# 1   sound natur reverber background come across fi...
# 2   addit exhibit includ uniqu paint artist puspa ...
# 3       prakriti-wher god resid full interest artwork
# 4   exhibit featur tradit modern artwork experienc...
# 5   anim seri exhibit showcas work artist lok chit...
# 6   exhibit also shiva parvati seri display work u...
# 7   prakriti-wher god resid also abstract paint th...
# 8   addit one wit finest statu differ god goddess ...
# 9   prakriti-wher god resid set preced curat tradi...
# 10  provid platform tradit artist ventur new realm...
# 11            shown adapt artist collabor quit beauti
# 12  follow new trend exhibit also display captiv d...
# 13  usual tradit artist reluct explor modern aspec...
# 14  howev exhibit viewer wit tradit artist raj pra...
# 15  prajwol shakya director galleri said “ object ...
# 16  ” moreov say exhibit celebr rich artist legaci...
# 17  likewis prakriti-wher god resid showcas never ...
# 18  one paint exhibit featur ceremoni newa commun ...
# 19  realist paint pleas eye work everi singl detai...
# 20  understand depth detail paint use magnifi glas...
# 21  look paint closer magnifi glass see shine clot...
# 22  “ usual newa commun bride welcom first time ho...
# 23  ” udaya charan known detail work one finest tr...
# 24  udaya charan also help envis iconograph imag g...
# 25  goddess annapurna known bless never-end suppli...
# 26  even shrine one asan devote limit wit kalash v...
# 27  howev late purna man shakya receiv order godde...
# 28  help udaya charan iconograph imag goddess anna...
# 29  exhibit wit life-s digit anim goddess annapurn...
# 30  similarli also see metal statu goddess annapur...
# 31  “ reson younger gener embrac modern technolog ...
# 32  ” exhibit let explor connected natur real spir...
# 33  addit exhibit demonstr willing establish artis...
# 34                     exhibit continu till august 26
# 35            shrestha senior sub-editor onlinekhabar
# 36                              contact email protect
